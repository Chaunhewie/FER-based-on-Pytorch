# %%
# %matplotlib inline

# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

dir_path = "../data/CK+48"

# %%
classes = os.listdir(dir_path)
print(classes)
for c in classes:
    path = os.path.join(dir_path, c)
    file_names = os.listdir(path)
    print(c, ":", len(file_names))
    for file_name in file_names:
        file_path = os.path.join(path, file_name)
        img = Image.open(file_path)
        fig = plt.figure()
        ax = fig.add_subplot(111)
        ax.imshow(np.array(img), cmap="gray")
        break
# Out:
# ['anger', 'contempt', 'disgust', 'fear', 'happy', 'sadness', 'surprise']
# anger : 135
# contempt : 54
# disgust : 177
# fear : 75
# happy : 207
# sadness : 84
# surprise : 249

# %%
print(os.listdir("../data/raw_data/CK+/cohn-kanade-images"))
# Out:
# ['S005', 'S010', 'S011', 'S014', 'S022', 'S026', 'S028', 'S029', 'S032', 'S034', 'S035', 'S037', 'S042', 'S044', 'S045', 'S046', 'S050', 'S051', 'S052', 'S053', 'S054', 'S055', 'S056', 'S057', 'S058', 'S059', 'S060', 'S061', 'S062', 'S063', 'S064', 'S065', 'S066', 'S067', 'S068', 'S069', 'S070', 'S071', 'S072', 'S073', 'S074', 'S075', 'S076', 'S077', 'S078', 'S079', 'S080', 'S081', 'S082', 'S083', 'S084', 'S085', 'S086', 'S087', 'S088', 'S089', 'S090', 'S091', 'S092', 'S093', 'S094', 'S095', 'S096', 'S097', 'S098', 'S099', 'S100', 'S101', 'S102', 'S103', 'S104', 'S105', 'S106', 'S107', 'S108', 'S109', 'S110', 'S111', 'S112', 'S113', 'S114', 'S115', 'S116', 'S117', 'S118', 'S119', 'S120', 'S121', 'S122', 'S124', 'S125', 'S126', 'S127', 'S128', 'S129', 'S130', 'S131', 'S132', 'S133', 'S134', 'S135', 'S136', 'S137', 'S138', 'S139', 'S147', 'S148', 'S149', 'S151', 'S154', 'S155', 'S156', 'S157', 'S158', 'S160', 'S501', 'S502', 'S503', 'S504', 'S505', 'S506', 'S895', 'S999']

# %%
l = ['S005', 'S010', 'S011', 'S014', 'S022', 'S026', 'S028', 'S029', 'S032', 'S034', 'S035', 'S037', 'S042', 'S044', 'S045', 'S046', 'S050', 'S051', 'S052', 'S053', 'S054', 'S055', 'S056', 'S057', 'S058', 'S059', 'S060', 'S061', 'S062', 'S063', 'S064', 'S065', 'S066', 'S067', 'S068', 'S069', 'S070', 'S071', 'S072', 'S073', 'S074', 'S075', 'S076', 'S077', 'S078', 'S079', 'S080', 'S081', 'S082', 'S083', 'S084', 'S085', 'S086', 'S087', 'S088', 'S089', 'S090', 'S091', 'S092', 'S093', 'S094', 'S095', 'S096', 'S097', 'S098', 'S099', 'S100', 'S101', 'S102', 'S103', 'S104', 'S105', 'S106', 'S107', 'S108', 'S109', 'S110', 'S111', 'S112', 'S113', 'S114', 'S115', 'S116', 'S117', 'S118', 'S119', 'S120', 'S121', 'S122', 'S124', 'S125', 'S126', 'S127', 'S128', 'S129', 'S130', 'S131', 'S132', 'S133', 'S134', 'S135', 'S136', 'S137', 'S138', 'S139', 'S147', 'S148', 'S149', 'S151', 'S154', 'S155', 'S156', 'S157', 'S158', 'S160', 'S501', 'S502', 'S503', 'S504', 'S505', 'S506', 'S895', 'S999']

# %%
import random
random.shuffle(l)
print(len(l))
# list1 = [l[] for i in ]
split_index = int(len(l)*1/10)
if split_index < 1:
    split_index = 1
print(split_index)
train_people_indexes = l[:-split_index]
test_people_indexes = l[-split_index:]
print(len(train_people_indexes),len(test_people_indexes))
# Out:
# 123
# 12
# 111 12

# %%
# Out:
# False False True False False False False False False
